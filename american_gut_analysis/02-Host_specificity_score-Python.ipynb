# %%
from glob import glob
from os import listdir, makedirs
from os.path import join
import pandas as pd
import numpy as np

# %%
group_sig_out_dir = './output/distance'

# %% [markdown]
# ## Import data

# %% [markdown]
# Get a list of all the files in the output group significance directory

# %%
taxa = listdir(group_sig_out_dir)

# %% [markdown]
# Iterate over each of the output files, and import the group significance results

# %%
# grab tsv files
bact_dfs = []
for d in taxa:
    data_fp = join(group_sig_out_dir,
                   d,
                   'permanova',
                   'raw_data.tsv')
    
    d_df = pd.read_csv(data_fp, 
                       header=0,
                       sep='\t',
                       index_col=0)

    d_df['Bacterial_Genus'] = d
    
    bact_dfs.append(d_df)
    

# load group significance tsvs

# %% [markdown]
# Combine these results into a single dataframe.

# %%
combined_df = pd.concat(bact_dfs, ignore_index=True)

# %%
combined_df.head()
# Out:
#           SubjectID1         SubjectID2                   Group1  \
# 0     65716.12173.91     65716.12173.92   chimp_TZA_wild_moeller
# 1     65716.12173.92  80072.12821.G2MB7   chimp_TZA_wild_moeller
# 2     65716.12173.91  80072.12821.G2MB7   chimp_TZA_wild_moeller
# 3  80072.12821.G2MB7     65716.12173.92  howler_CRI_wild_clayton
# 4  80072.12821.G2MB7     65716.12173.91  howler_CRI_wild_clayton
#
#                     Group2  Distance  \
# 0   chimp_TZA_wild_moeller       1.0
# 1  howler_CRI_wild_clayton       1.0
# 2  howler_CRI_wild_clayton       1.0
# 3   chimp_TZA_wild_moeller       1.0
# 4   chimp_TZA_wild_moeller       1.0
#
#                                      Bacterial_Genus
# 0  k__Archaea_p__Crenarchaeota_c__Thaumarchaeota_...
# 1  k__Archaea_p__Crenarchaeota_c__Thaumarchaeota_...
# 2  k__Archaea_p__Crenarchaeota_c__Thaumarchaeota_...
# 3  k__Archaea_p__Crenarchaeota_c__Thaumarchaeota_...
# 4  k__Archaea_p__Crenarchaeota_c__Thaumarchaeota_...

# %% [markdown]
# ## Aggregate distance values

# %% [markdown]
# Using the Pandas pivot table functionality, aggregate the individual dissimilarity comparisons by group using `np.mean`.

# %%
combined_pivot = combined_df.pivot_table(values='Distance',
                        index=['Group1', 'Group2'],
                        columns=['Bacterial_Genus'],
                        aggfunc=np.mean)

# %%
combined_pivot.reset_index(inplace=True)

# %%
combined_pivot.head()
# Out:
# Bacterial_Genus                   Group1                      Group2  \
# 0                chimp_DRC_wild_campbell     chimp_DRC_wild_campbell
# 1                chimp_DRC_wild_campbell      chimp_TZA_wild_moeller
# 2                chimp_DRC_wild_campbell  chimp_USA_captive_campbell
# 3                chimp_DRC_wild_campbell   chimp_USA_captive_moeller
# 4                chimp_DRC_wild_campbell    douc_SGP_captive_clayton
#
# Bacterial_Genus  Unassigned_____  \
# 0                       0.952381
# 1                            NaN
# 2                       1.000000
# 3                            NaN
# 4                            NaN
#
# Bacterial_Genus  k__Archaea_p__Crenarchaeota_c__Thaumarchaeota_o__Nitrososphaerales_f__Nitrososphaeraceae_g__CandidatusNitrososphaera  \
# 0                                                              NaN
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
#
# Bacterial_Genus  k__Archaea_p__Euryarchaeota_c__Methanobacteria_o__Methanobacteriales_f__Methanobacteriaceae_g__Methanobrevibacter  \
# 0                                                              NaN
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
#
# Bacterial_Genus  k__Archaea_p__Euryarchaeota_c__Methanobacteria_o__Methanobacteriales_f__Methanobacteriaceae_g__Methanosphaera  \
# 0                                                         0.476190
# 1                                                         0.346599
# 2                                                         0.625661
# 3                                                         0.619048
# 4                                                         0.699134
#
# Bacterial_Genus  k__Archaea_p__Euryarchaeota_c__Thermoplasmata_o__E2_f__[Methanomassiliicoccaceae]_g__vadinCA11  \
# 0                                                         0.222222
# 1                                                         0.507755
# 2                                                         0.610979
# 3                                                         0.685714
# 4                                                         1.000000
#
# Bacterial_Genus  k__Bacteria_____  \
# 0                        0.844795
# 1                        0.944939
# 2                        0.966638
# 3                        0.985043
# 4                        0.998055
#
# Bacterial_Genus  k__Bacteria_p__Acidobacteria_c__Acidobacteria-6_o__iii1-15_f___g__  \
# 0                                                            1.000
# 1                                                            0.975
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
#
# Bacterial_Genus  k__Bacteria_p__Acidobacteria_c__Acidobacteria-6_o__iii1-15_f__mb2424_g__  \
# 0                                                              NaN
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
#
# Bacterial_Genus  ...  \
# 0                ...
# 1                ...
# 2                ...
# 3                ...
# 4                ...
#
# Bacterial_Genus  k__Bacteria_p__Tenericutes_c__Mollicutes_o__Mycoplasmatales_f__Mycoplasmataceae_g__  \
# 0                                                         1.000000
# 1                                                         0.638889
# 2                                                         1.000000
# 3                                                              NaN
# 4                                                              NaN
#
# Bacterial_Genus  k__Bacteria_p__Tenericutes_c__Mollicutes_o__RF39_f___g__  \
# 0                                                         0.626793
# 1                                                         0.794204
# 2                                                         0.866128
# 3                                                         0.893772
# 4                                                         0.995097
#
# Bacterial_Genus  k__Bacteria_p__Tenericutes_c__RF3_o__ML615J-28_f___g__  \
# 0                                                         1.000000
# 1                                                         0.779603
# 2                                                         0.878175
# 3                                                         0.950000
# 4                                                         1.000000
#
# Bacterial_Genus  k__Bacteria_p__Verrucomicrobia_c__Opitutae_o__HA64_f___g__  \
# 0                                                         0.400000
# 1                                                         0.211348
# 2                                                         1.000000
# 3                                                         1.000000
# 4                                                         1.000000
#
# Bacterial_Genus  k__Bacteria_p__Verrucomicrobia_c__Opitutae_o__[Cerasicoccales]_f__[Cerasicoccaceae]_g__  \
# 0                                                         0.222222
# 1                                                         0.507755
# 2                                                         0.610979
# 3                                                         0.685714
# 4                                                         1.000000
#
# Bacterial_Genus  k__Bacteria_p__Verrucomicrobia_c__Verruco-5_o__WCHB1-41_f__RFP12_g__  \
# 0                                                         0.684271
# 1                                                         0.714956
# 2                                                         1.000000
# 3                                                         1.000000
# 4                                                         1.000000
#
# Bacterial_Genus  k__Bacteria_p__Verrucomicrobia_c__Verrucomicrobiae_o__Verrucomicrobiales_f__Verrucomicrobiaceae_g__Akkermansia  \
# 0                                                              NaN
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
#
# Bacterial_Genus  k__Bacteria_p__Verrucomicrobia_c__[Spartobacteria]_o__[Chthoniobacterales]_f__[Chthoniobacteraceae]_g__DA101  \
# 0                                                              NaN
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
#
# Bacterial_Genus  k__Bacteria_p__WPS-2_c___o___f___g__  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
#
# Bacterial_Genus  k__Bacteria_p___c___o___f___g__
# 0                                       0.000000
# 1                                       0.012658
# 2                                       1.000000
# 3                                            NaN
# 4                                            NaN
#
# [5 rows x 236 columns]

# %% [markdown]
# ## Load target group comparisons

# %% [markdown]
# This file should list just the specific group comparisons we want to look at.

# %%
target_grp_df = pd.read_csv('./data/host_specificity_score_populations_american_gut.txt', sep='\t')

# %%
target_grp_df
# Out:
#              captive_population human_population            wild_population
# 0      douc_USA_captive_clayton        human_USA      douc_VNM_wild_clayton
# 1      douc_SGP_captive_clayton        human_USA      douc_VNM_wild_clayton
# 2     chimp_USA_captive_moeller        human_USA     chimp_TZA_wild_moeller
# 3    chimp_USA_captive_campbell        human_USA    chimp_DRC_wild_campbell
# 4    howler_CRI_captive_clayton        human_USA    howler_CRI_wild_clayton
# 5  gorilla_USA_captive_campbell        human_USA  gorilla_DRC_wild_campbell
# 6  douc_VNM_semicaptive_clayton        human_USA      douc_VNM_wild_clayton

# %% [markdown]
# ## Filter data list to target comparisons

# %% [markdown]
# Update the aggregated pivot table to include the comparison number and comparison direction (captive to human or captive to wild) as additional columns

# %%
combined_pivot['comparison_num'] = 'None'
combined_pivot['comparison_dir'] = 'None'

for i, row in target_grp_df.iterrows():
    combined_pivot.loc[(combined_pivot['Group1'] == row['captive_population']) &
                       (combined_pivot['Group2'] == row['human_population']),
                       'comparison_num'] = i
    combined_pivot.loc[(combined_pivot['Group1'] == row['captive_population']) &
                       (combined_pivot['Group2'] == row['human_population']),
                       'comparison_dir'] = 'human'
    combined_pivot.loc[(combined_pivot['Group1'] == row['captive_population']) &
                       (combined_pivot['Group2'] == row['wild_population']),
                       'comparison_num'] = i
    combined_pivot.loc[(combined_pivot['Group1'] == row['captive_population']) &
                       (combined_pivot['Group2'] == row['wild_population']),
                       'comparison_dir'] = 'wild'

# %% [markdown]
# Remove non-target comparisons from the table

# %%
combined_pivot_filtered = combined_pivot.loc[(combined_pivot['comparison_num'] != 'None'),]

# %%
combined_pivot_filtered
# Out:
# Bacterial_Genus                        Group1                     Group2  \
# 24                 chimp_USA_captive_campbell    chimp_DRC_wild_campbell
# 35                 chimp_USA_captive_campbell                  human_USA
# 37                  chimp_USA_captive_moeller     chimp_TZA_wild_moeller
# 47                  chimp_USA_captive_moeller                  human_USA
# 54                   douc_SGP_captive_clayton      douc_VNM_wild_clayton
# 59                   douc_SGP_captive_clayton                  human_USA
# 66               douc_VNM_semicaptive_clayton      douc_VNM_wild_clayton
# 71               douc_VNM_semicaptive_clayton                  human_USA
# 103              gorilla_USA_captive_campbell  gorilla_DRC_wild_campbell
# 107              gorilla_USA_captive_campbell                  human_USA
# 118                howler_CRI_captive_clayton    howler_CRI_wild_clayton
# 119                howler_CRI_captive_clayton                  human_USA
#
# Bacterial_Genus  Unassigned_____  \
# 24                           1.0
# 35                           NaN
# 37                           NaN
# 47                           NaN
# 54                           NaN
# 59                           NaN
# 66                           NaN
# 71                           NaN
# 103                          NaN
# 107                          NaN
# 118                          NaN
# 119                          NaN
#
# Bacterial_Genus  k__Archaea_p__Crenarchaeota_c__Thaumarchaeota_o__Nitrososphaerales_f__Nitrososphaeraceae_g__CandidatusNitrososphaera  \
# 24                                                             NaN
# 35                                                             NaN
# 37                                                             NaN
# 47                                                             NaN
# 54                                                             NaN
# 59                                                             NaN
# 66                                                             NaN
# 71                                                             NaN
# 103                                                            NaN
# 107                                                            NaN
# 118                                                            NaN
# 119                                                            NaN
#
# Bacterial_Genus  k__Archaea_p__Euryarchaeota_c__Methanobacteria_o__Methanobacteriales_f__Methanobacteriaceae_g__Methanobrevibacter  \
# 24                                                             NaN
# 35                                                             NaN
# 37                                                             NaN
# 47                                                             NaN
# 54                                                             NaN
# 59                                                             1.0
# 66                                                             NaN
# 71                                                             NaN
# 103                                                            NaN
# 107                                                            NaN
# 118                                                            NaN
# 119                                                            NaN
#
# Bacterial_Genus  k__Archaea_p__Euryarchaeota_c__Methanobacteria_o__Methanobacteriales_f__Methanobacteriaceae_g__Methanosphaera  \
# 24                                                        0.625661
# 35                                                        0.018519
# 37                                                        0.928571
# 47                                                        0.000000
# 54                                                             NaN
# 59                                                        0.212121
# 66                                                             NaN
# 71                                                        0.875000
# 103                                                       0.833333
# 107                                                       0.000000
# 118                                                            NaN
# 119                                                            NaN
#
# Bacterial_Genus  k__Archaea_p__Euryarchaeota_c__Thermoplasmata_o__E2_f__[Methanomassiliicoccaceae]_g__vadinCA11  \
# 24                                                        0.610979
# 35                                                        1.000000
# 37                                                        0.513061
# 47                                                        1.000000
# 54                                                        1.000000
# 59                                                        1.000000
# 66                                                        1.000000
# 71                                                        1.000000
# 103                                                       0.840678
# 107                                                       1.000000
# 118                                                            NaN
# 119                                                            NaN
#
# Bacterial_Genus  k__Bacteria_____  \
# 24                       0.966638
# 35                       0.998805
# 37                       0.940518
# 47                       0.998232
# 54                       0.981906
# 59                       0.992915
# 66                       0.905775
# 71                       1.000000
# 103                      0.992406
# 107                      0.994426
# 118                      0.835300
# 119                      1.000000
#
# Bacterial_Genus  k__Bacteria_p__Acidobacteria_c__Acidobacteria-6_o__iii1-15_f___g__  \
# 24                                                             NaN
# 35                                                             NaN
# 37                                                             NaN
# 47                                                             NaN
# 54                                                             NaN
# 59                                                             NaN
# 66                                                             NaN
# 71                                                             NaN
# 103                                                            NaN
# 107                                                            NaN
# 118                                                            NaN
# 119                                                            NaN
#
# Bacterial_Genus  k__Bacteria_p__Acidobacteria_c__Acidobacteria-6_o__iii1-15_f__mb2424_g__  \
# 24                                                             NaN
# 35                                                             NaN
# 37                                                        0.210526
# 47                                                             NaN
# 54                                                             NaN
# 59                                                             NaN
# 66                                                             NaN
# 71                                                             NaN
# 103                                                            NaN
# 107                                                            NaN
# 118                                                            NaN
# 119                                                            NaN
#
# Bacterial_Genus  ...  k__Bacteria_p__Tenericutes_c__RF3_o__ML615J-28_f___g__  \
# 24               ...                                           0.878175
# 35               ...                                           0.980938
# 37               ...                                           0.921071
# 47               ...                                           0.965000
# 54               ...                                           0.831372
# 59               ...                                           1.000000
# 66               ...                                           0.730686
# 71               ...                                           1.000000
# 103              ...                                           1.000000
# 107              ...                                           0.984683
# 118              ...                                                NaN
# 119              ...                                                NaN
#
# Bacterial_Genus  k__Bacteria_p__Verrucomicrobia_c__Opitutae_o__HA64_f___g__  \
# 24                                                             1.0
# 35                                                             NaN
# 37                                                             1.0
# 47                                                             NaN
# 54                                                             NaN
# 59                                                             NaN
# 66                                                             NaN
# 71                                                             NaN
# 103                                                            NaN
# 107                                                            NaN
# 118                                                            NaN
# 119                                                            NaN
#
# Bacterial_Genus  k__Bacteria_p__Verrucomicrobia_c__Opitutae_o__[Cerasicoccales]_f__[Cerasicoccaceae]_g__  \
# 24                                                        0.610979
# 35                                                        1.000000
# 37                                                        0.513061
# 47                                                        1.000000
# 54                                                        1.000000
# 59                                                        1.000000
# 66                                                        1.000000
# 71                                                        1.000000
# 103                                                       0.840678
# 107                                                       1.000000
# 118                                                            NaN
# 119                                                            NaN
#
# Bacterial_Genus  k__Bacteria_p__Verrucomicrobia_c__Verruco-5_o__WCHB1-41_f__RFP12_g__  \
# 24                                                        1.000000
# 35                                                             NaN
# 37                                                        0.926907
# 47                                                             NaN
# 54                                                             NaN
# 59                                                             NaN
# 66                                                             NaN
# 71                                                             NaN
# 103                                                       1.000000
# 107                                                            NaN
# 118                                                            NaN
# 119                                                            NaN
#
# Bacterial_Genus  k__Bacteria_p__Verrucomicrobia_c__Verrucomicrobiae_o__Verrucomicrobiales_f__Verrucomicrobiaceae_g__Akkermansia  \
# 24                                                             NaN
# 35                                                        0.298246
# 37                                                        0.666667
# 47                                                        0.376218
# 54                                                        0.877683
# 59                                                        0.385526
# 66                                                        0.321829
# 71                                                        0.961014
# 103                                                            NaN
# 107                                                       0.532164
# 118                                                       0.712963
# 119                                                       0.532164
#
# Bacterial_Genus  k__Bacteria_p__Verrucomicrobia_c__[Spartobacteria]_o__[Chthoniobacterales]_f__[Chthoniobacteraceae]_g__DA101  \
# 24                                                             NaN
# 35                                                             NaN
# 37                                                             NaN
# 47                                                             NaN
# 54                                                             NaN
# 59                                                             NaN
# 66                                                             NaN
# 71                                                             NaN
# 103                                                            NaN
# 107                                                            NaN
# 118                                                            NaN
# 119                                                            NaN
#
# Bacterial_Genus  k__Bacteria_p__WPS-2_c___o___f___g__  \
# 24                                                NaN
# 35                                                NaN
# 37                                           0.210526
# 47                                                NaN
# 54                                                NaN
# 59                                                NaN
# 66                                                NaN
# 71                                                NaN
# 103                                               NaN
# 107                                               NaN
# 118                                               NaN
# 119                                               NaN
#
# Bacterial_Genus  k__Bacteria_p___c___o___f___g__  comparison_num  \
# 24                                           1.0               3
# 35                                           1.0               3
# 37                                           NaN               2
# 47                                           NaN               2
# 54                                           NaN               1
# 59                                           NaN               1
# 66                                           NaN               6
# 71                                           NaN               6
# 103                                          NaN               5
# 107                                          NaN               5
# 118                                          NaN               4
# 119                                          NaN               4
#
# Bacterial_Genus  comparison_dir
# 24                         wild
# 35                        human
# 37                         wild
# 47                        human
# 54                         wild
# 59                        human
# 66                         wild
# 71                        human
# 103                        wild
# 107                       human
# 118                        wild
# 119                       human
#
# [12 rows x 238 columns]

# %% [markdown]
# ## Calculate HSS

# %% [markdown]
# First, transpose and set column indexed on the combined filtered dataframe so that taxon is the row index and comparison number / comparison direction are a column MultiIndex

# %%
combined_pivot_filtered_t = combined_pivot_filtered.drop(columns=['Group1', 'Group2']).set_index(['comparison_num',
                                                                            'comparison_dir']).transpose()

# %%
combined_pivot_filtered_t.head()
# Out:
# comparison_num                                             3            \
# comparison_dir                                          wild     human
# Bacterial_Genus
# Unassigned_____                                     1.000000       NaN
# k__Archaea_p__Crenarchaeota_c__Thaumarchaeota_o...       NaN       NaN
# k__Archaea_p__Euryarchaeota_c__Methanobacteria_...       NaN       NaN
# k__Archaea_p__Euryarchaeota_c__Methanobacteria_...  0.625661  0.018519
# k__Archaea_p__Euryarchaeota_c__Thermoplasmata_o...  0.610979  1.000000
#
# comparison_num                                             2          1  \
# comparison_dir                                          wild human wild
# Bacterial_Genus
# Unassigned_____                                          NaN   NaN  NaN
# k__Archaea_p__Crenarchaeota_c__Thaumarchaeota_o...       NaN   NaN  NaN
# k__Archaea_p__Euryarchaeota_c__Methanobacteria_...       NaN   NaN  NaN
# k__Archaea_p__Euryarchaeota_c__Methanobacteria_...  0.928571   0.0  NaN
# k__Archaea_p__Euryarchaeota_c__Thermoplasmata_o...  0.513061   1.0  1.0
#
# comparison_num                                                  6         \
# comparison_dir                                         human wild  human
# Bacterial_Genus
# Unassigned_____                                          NaN  NaN    NaN
# k__Archaea_p__Crenarchaeota_c__Thaumarchaeota_o...       NaN  NaN    NaN
# k__Archaea_p__Euryarchaeota_c__Methanobacteria_...  1.000000  NaN    NaN
# k__Archaea_p__Euryarchaeota_c__Methanobacteria_...  0.212121  NaN  0.875
# k__Archaea_p__Euryarchaeota_c__Thermoplasmata_o...  1.000000  1.0  1.000
#
# comparison_num                                             5          4
# comparison_dir                                          wild human wild human
# Bacterial_Genus
# Unassigned_____                                          NaN   NaN  NaN   NaN
# k__Archaea_p__Crenarchaeota_c__Thaumarchaeota_o...       NaN   NaN  NaN   NaN
# k__Archaea_p__Euryarchaeota_c__Methanobacteria_...       NaN   NaN  NaN   NaN
# k__Archaea_p__Euryarchaeota_c__Methanobacteria_...  0.833333   0.0  NaN   NaN
# k__Archaea_p__Euryarchaeota_c__Thermoplasmata_o...  0.840678   1.0  NaN   NaN

# %%
target_grps = target_grp_df.copy()

# %%
target_grps.drop(columns=['human_population', 'wild_population'], 
                inplace=True)

# %%
HSS_df = pd.DataFrame(index=combined_pivot_filtered_t.index, 
                      columns=target_grps.index)

for i, row in target_grps.iterrows():
    HSS = combined_pivot_filtered_t.loc[:,(i,
                     'human')]/combined_pivot_filtered_t.loc[:,(i,
                                          'wild')]
    HSS_df[i] = HSS
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/qiime2-2021.2/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.BaseMultiIndexCodesEngine.get_loc()
#
# ~/miniconda3/envs/qiime2-2021.2/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-3488705c67fb> in <module>
#       4 for i, row in target_grps.iterrows():
#       5     HSS = combined_pivot_filtered_t.loc[:,(i,
# ----> 6                      'human')]/combined_pivot_filtered_t.loc[:,(i,
#       7                                           'wild')]
#       8     HSS_df[i] = HSS
#
# ~/miniconda3/envs/qiime2-2021.2/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# ~/miniconda3/envs/qiime2-2021.2/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1042     def _getitem_tuple(self, tup: Tuple):
#    1043         try:
# -> 1044             return self._getitem_lowerdim(tup)
#    1045         except IndexingError:
#    1046             pass
#
# ~/miniconda3/envs/qiime2-2021.2/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     764         # we may have a nested tuples indexer here
#     765         if self._is_nested_tuple_indexer(tup):
# --> 766             return self._getitem_nested_tuple(tup)
#     767
#     768         # we maybe be using a tuple to represent multiple dimensions here
#
# ~/miniconda3/envs/qiime2-2021.2/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_nested_tuple(self, tup)
#     845
#     846             current_ndim = obj.ndim
# --> 847             obj = getattr(obj, self.name)._getitem_axis(key, axis=axis)
#     848             axis += 1
#     849
#
# ~/miniconda3/envs/qiime2-2021.2/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1108         # fall thru to straight lookup
#    1109         self._validate_key(key, axis)
# -> 1110         return self._get_label(key, axis=axis)
#    1111
#    1112     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~/miniconda3/envs/qiime2-2021.2/lib/python3.6/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1057     def _get_label(self, label, axis: int):
#    1058         # GH#5667 this will fail if the label is not present in the axis.
# -> 1059         return self.obj.xs(label, axis=axis)
#    1060
#    1061     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# ~/miniconda3/envs/qiime2-2021.2/lib/python3.6/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3483
#    3484         if axis == 1:
# -> 3485             return self[key]
#    3486
#    3487         self._consolidate_inplace()
#
# ~/miniconda3/envs/qiime2-2021.2/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2903         if is_single_key:
#    2904             if self.columns.nlevels > 1:
# -> 2905                 return self._getitem_multilevel(key)
#    2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#
# ~/miniconda3/envs/qiime2-2021.2/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_multilevel(self, key)
#    2953     def _getitem_multilevel(self, key):
#    2954         # self.columns is a MultiIndex
# -> 2955         loc = self.columns.get_loc(key)
#    2956         if isinstance(loc, (slice, np.ndarray)):
#    2957             new_columns = self.columns[loc]
#
# ~/miniconda3/envs/qiime2-2021.2/lib/python3.6/site-packages/pandas/core/indexes/multi.py in get_loc(self, key, method)
#    2712
#    2713         if keylen == self.nlevels and self.is_unique:
# -> 2714             return self._engine.get_loc(key)
#    2715
#    2716         # -- partial selection or non-unique index
#
# pandas/_libs/index.pyx in pandas._libs.index.BaseMultiIndexCodesEngine.get_loc()
#
# KeyError: (0, 'human')

# %%
HSS_df.head()

# %% [markdown]
# Make this pretty; add back in the comparison names

# %%
a = HSS_df.transpose()
a

# %%
target_grp_df.columns

# %%
final_table = a.merge(target_grp_df,
                      left_index=True,
                      right_index=True).set_index(list(target_grp_df.columns)).transpose()

# %%
final_table.head()

# %% [markdown]
# Write to file

# %%
outdir = join('output', 'results')
makedirs(outdir, exist_ok=True)
final_table.to_csv(join(outdir, 'hss_american_gut.txt'), sep='\t')
